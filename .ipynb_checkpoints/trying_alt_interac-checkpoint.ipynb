# %%
import pandas as pd
import altair as alt
from ipywidgets import interact

# %%
# Data Loading 
attention = pd.read_stata("../HW/static_project/attended_09_19.dta")
attention_peru = attention.loc[attention['dpto'] == 0]
attention_reg = attention.loc[attention['dpto'] != 0]

# %%
attention_reg
# Out:
#              dpto       dpto_str  targeted  upto_2019  upto2009  total_dist  \
# 0        Amazonas       Amazonas      35.0        8.0       4.0        84.0
# 1          Ancash         Ancash      92.0       46.0      24.0       166.0
# 2        Apurimac       Apurimac      78.0       26.0      12.0        84.0
# 3        Arequipa       Arequipa      39.0       47.0      35.0       109.0
# 4        Ayacucho       Ayacucho     109.0       33.0      15.0       119.0
# 5       Cajamarca      Cajamarca     126.0       11.0       9.0       128.0
# 6          Callao         Callao       3.0        3.0       2.0         7.0
# 7           Cusco          Cusco      76.0       31.0      19.0       112.0
# 8    Huancavelica   Huancavelica      78.0       30.0      26.0       100.0
# 9         Huanuco        Huanuco      77.0       22.0       8.0        84.0
# 10            Ica            Ica      21.0       28.0      13.0        43.0
# 11          Junin          Junin      97.0       63.0      28.0       124.0
# 12    La Libertad    La Libertad      72.0       19.0       4.0        83.0
# 13     Lambayeque     Lambayeque      30.0       24.0       5.0        38.0
# 14           Lima           Lima      64.0       58.0      37.0       171.0
# 15         Loreto         Loreto      53.0       11.0       8.0        53.0
# 16  Madre de Dios  Madre de Dios      11.0        1.0       0.0        11.0
# 17       Moquegua       Moquegua       3.0        3.0       3.0        20.0
# 18          Pasco          Pasco      29.0       16.0       8.0        29.0
# 19          Piura          Piura      53.0       23.0      10.0        65.0
# 20           Puno           Puno      92.0       25.0      12.0       110.0
# 21     San Martin     San Martin      48.0       17.0       5.0        77.0
# 22          Tacna          Tacna      14.0       13.0       4.0        28.0
# 23         Tumbes         Tumbes      10.0       10.0       0.0        13.0
# 24        Ucayali        Ucayali      17.0       10.0       6.0        17.0
#
#     region
# 0   Sierra
# 1    Costa
# 2   Sierra
# 3    Costa
# 4   Sierra
# 5   Sierra
# 6    Costa
# 7   Sierra
# 8   Sierra
# 9   Sierra
# 10   Costa
# 11  Sierra
# 12   Costa
# 13   Costa
# 14   Costa
# 15   Selva
# 16   Selva
# 17   Costa
# 18  Sierra
# 19   Costa
# 20  Sierra
# 21  Sierra
# 22   Costa
# 23   Costa
# 24   Selva

# %%
# Chart 2 
chart2=alt.layer(
    alt.Chart(attention_peru).mark_bar(color='#eee').encode(alt.X("total_dist:Q", scale=alt.Scale(nice=False), title=None)),
    alt.Chart(attention_peru).mark_bar().encode(color=alt.Color('measures[0]:N', scale=alt.Scale(domain=["2009", "2019", "Targeted districts"], range=["#d62728", "#ff9896", "black"]))),
    alt.Chart(attention_peru).mark_bar(color='#ff9896', size=10).encode(x='upto_2019:Q', ),
        alt.Chart(attention_peru).mark_bar(color='#d62728', size=10).encode(x='upto2009:Q', ),
    alt.Chart(attention_peru).mark_tick(color='black', thickness=2).encode(x='targeted:Q'),
    width=350,
    height=30).facet(
        title={"text": ["Regions differ vastly in total and targeted districts", "Expansion of CunaMas has been heterogeneous"], 
                        "subtitle": ["", "Number of attended districts by region", ""],
                        "color": "black", "subtitleColor": "black", "align":"center", 
                        "font": "LM Roman", "fontSize":20, "fontWeight": "bold",}, 
        row=alt.Row("dpto_str:O", sort=['Peru'], title=None)
        ).resolve_scale(x='independent')

chart2 = alt.concat(chart2,
    title=alt.TitleParams(
        'Source: CunaMas Administrative Records',
        baseline='bottom',
        orient='none',
        anchor='end',
        dx=375, dy=105,
        fontSize=10))
                      
chart2.configure_legend(title=None, direction='horizontal', orient="none", 
                      legendX=75, legendY=65, padding=5, rowPadding=5, 
                      strokeColor='Gray').configure_title(
                          fontSize=20, offset=5, orient='top', anchor='middle')
# Out:
# alt.ConcatChart(...)

# %%
# Chart 2
checkboxes = alt.binding_select(name='Natural Region: ', options=[None]+list(attention_reg["region"].unique())
                                ,labels=['All Regions']+ list(attention_reg["region"].unique()))
selection = alt.selection_single(fields=['region'], bind=checkboxes, name='Natural Region ')
color = alt.condition(selection,
                    alt.Color('region:N', legend=None),
                    alt.value('lightgray'))

regions = pd.DataFrame({'region': ['Costa', 'Sierra', 'Selva']})
                                   
                                    
chart2=alt.layer(alt.Chart(regions).mark_rect().encode(y='region', color=color).add_selection(selection),
    alt.Chart(attention_reg).mark_bar(color='#eee').encode(alt.X("total_dist:Q", scale=alt.Scale(nice=False), title=None)),
    alt.Chart(attention_reg).mark_bar().encode(color=alt.Color('measures[0]:N', scale=alt.Scale(domain=["2009", "2019", "Targeted districts"], range=["#d62728", "#ff9896", "black"]))),
    alt.Chart(attention_reg).mark_bar(color='#ff9896', size=10).encode(x='upto_2019:Q', ),
        alt.Chart(attention_reg).mark_bar(color='#d62728', size=10).encode(x='upto2009:Q', ),
    alt.Chart(attention_reg).mark_tick(color='black', thickness=2).encode(x='targeted:Q'),
    width=350,
    height=30).facet(
        title={"text": ["Regions differ vastly in total and targeted districts", "Expansion of CunaMas has been heterogeneous"], 
                        "subtitle": ["", "Number of attended districts by region", ""],
                        "color": "black", "subtitleColor": "black", "align":"center", 
                        "font": "LM Roman", "fontSize":20, "fontWeight": "bold",}, 
        row=alt.Row("dpto_str:O", sort=['Peru'], title=None)
        ).resolve_scale(x='independent')

chart2 = alt.concat(chart2,
    title=alt.TitleParams(
        'Source: CunaMas Administrative Records',
        baseline='bottom',
        orient='none',
        anchor='end',
        dx=375, dy=105,
        fontSize=10))
                      
chart2.configure_legend(title=None, direction='horizontal', orient="none", 
                      legendX=75, legendY=65, padding=5, rowPadding=5, 
                      strokeColor='Gray').configure_title(
                          fontSize=20, offset=5, orient='top', anchor='middle')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-312-aec7a48af745> in <module>
#      22                         "color": "black", "subtitleColor": "black", "align":"center",
#      23                         "font": "LM Roman", "fontSize":20, "fontWeight": "bold",},
# ---> 24         row=alt.Row("dpto_str:O", sort=['Peru'], title=None)
#      25         ).resolve_scale(x='independent')
#      26
#
# ~\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in facet(self, facet, row, column, data, columns, **kwargs)
#    1862             if self.data is Undefined:
#    1863                 raise ValueError(
# -> 1864                     "Facet charts require data to be specified at the top level."
#    1865                 )
#    1866             self = self.copy(deep=False)
#
# ValueError: Facet charts require data to be specified at the top level.

# %% [markdown]
# ## This is drop down graphic

# %%
ex = pd.read_csv(r'./data/example1.csv', parse_dates = ['year'], date_parser=lambda x:pd.to_datetime(x, format='%Y'))
ex['year'] = ex['year'].dt.strftime('%Y')
ex
# Out:
#      year                group          outcome     value
# 0    2008             Attended  Moderate Anemia  0.096230
# 1    2008             Attended      Mild Anemia  0.187538
# 2    2008         Not targeted  Moderate Anemia  0.073884
# 3    2008         Not targeted      Mild Anemia  0.153815
# 4    2008  Target not attended  Moderate Anemia  0.114548
# ..    ...                  ...              ...       ...
# 175  2018             Attended     Men with job  0.766125
# 176  2018  Target not attended     Men with job  0.830474
# 177  2019         Not targeted     Men with job  0.751783
# 178  2019             Attended     Men with job  0.771814
# 179  2019  Target not attended     Men with job  0.835747
#
# [180 rows x 4 columns]

# %%
my_cmap = {
    'Not targeted': '#fdc1c5',
    'Attended': '#fc824a',
    'Target not attended': '#9f2305',
}

title = ["This is the title"]
subtitle = ["and this the subtitle"] 

dropdown_indicator = alt.binding_select(name='Indicator: ', options=[None]+list(ex["outcome"].unique())
                                       ,labels=['All Indicators']+ list(ex["outcome"].unique()))
dropdown_comparison = alt.binding_select(name='Zoom Group: ', options=[None]+list(ex["group"].unique())
                                         ,labels=['All Groups']+ list(ex["group"].unique()))
#year_slider = alt.binding_range(min=2008, max=2019, step=1)

selection_indicator = alt.selection_single(fields=["outcome"], bind=dropdown_indicator)
selection_comparison = alt.selection_single(fields=["group"], bind=dropdown_comparison)
#slider_selection = alt.selection_single(bind=year_slider, fields=['year'], name="year")

chart = alt.Chart(ex).mark_line().encode(
    x=alt.X('year:T', title="Year", scale=alt.Scale(zero=False), 
            axis=alt.Axis(grid=False)), 
    y=alt.Y('value', title="Share in %", scale=alt.Scale(zero=False)),
    color=alt.Color('group', title='',
                    scale=alt.Scale(
                        domain=list(my_cmap.keys()), 
                        range=list(my_cmap.values())),
                    legend=alt.Legend(
                        title="Districts", 
                        #orient='top-left',
                        #direction = 'horizontal',
                        legendX=235, legendY=151, padding=2, 
                        rowPadding=5, strokeColor='Gray')),
    tooltip= [alt.Tooltip('group:N'),
               alt.Tooltip('value:Q'),
               alt.Tooltip('year:T')
              ])


chart = chart.add_selection(selection_comparison, selection_indicator, #slider_selection,
            ).transform_filter(selection_comparison
            ).transform_filter(selection_indicator
            )#.transform_filter(slider_selection)

chart = chart.properties(title={ "text": title,  "subtitle": subtitle,
                        "color": "black", "subtitleColor": "black", "align":"center", 
                        "font": "LM Roman", "fontSize":20, "fontWeight": "bold",},
                        width=400, height=300)


chart = alt.concat(chart,
    title=alt.TitleParams(
        'Source: DHS 2009-2019',
        baseline='bottom',
        orient='none',
        dx=400, dy=350,
        anchor='end',
        fontSize=10))

chart
# Out:
# alt.ConcatChart(...)
